# %%
import pandas as pd

# %%
df = pd.read_csv('df_ann_analysys.csv')

# %%
df
# Out:
#     Iteration Category  Group  Correct Predictions  Incorrect Predictions
# 0           0      Age      0                  225                    157
# 1           0      Age      1                  588                    190
# 2           0      Age      2                10505                   3082
# 3           0      Age      3                 2123                    510
# 4           1      Age      0                  206                    143
# ..        ...      ...    ...                  ...                    ...
# 65          8   Gender      1                 7662                   2239
# 66          8   Gender      2                 5508                   1607
# 67          9   Gender      0                  234                    150
# 68          9   Gender      1                 7669                   2204
# 69          9   Gender      2                 5479                   1644
#
# [70 rows x 5 columns]

# %%
df[df['Iteration']==0]
# Out:
#     Iteration Category  Group  Correct Predictions  Incorrect Predictions
# 0           0      Age      0                  225                    157
# 1           0      Age      1                  588                    190
# 2           0      Age      2                10505                   3082
# 3           0      Age      3                 2123                    510
# 40          0   Gender      0                  225                    157
# 41          0   Gender      1                 7612                   2137
# 42          0   Gender      2                 5604                   1645

# %%
df['Error Rate'] = df['Incorrect Predictions'] / (df['Correct Predictions'] + df['Incorrect Predictions'])
df
# Out:
#     Iteration Category  Group  Correct Predictions  Incorrect Predictions  \
# 0           0      Age      0                  225                    157
# 1           0      Age      1                  588                    190
# 2           0      Age      2                10505                   3082
# 3           0      Age      3                 2123                    510
# 4           1      Age      0                  206                    143
# ..        ...      ...    ...                  ...                    ...
# 65          8   Gender      1                 7662                   2239
# 66          8   Gender      2                 5508                   1607
# 67          9   Gender      0                  234                    150
# 68          9   Gender      1                 7669                   2204
# 69          9   Gender      2                 5479                   1644
#
#     Error Rate
# 0     0.410995
# 1     0.244216
# 2     0.226834
# 3     0.193695
# 4     0.409742
# ..         ...
# 65    0.226139
# 66    0.225861
# 67    0.390625
# 68    0.223235
# 69    0.230802
#
# [70 rows x 6 columns]

# %%
error_by_group = df.groupby(['Category', 'Group'])['Error Rate'].mean()
print(error_by_group)
# Out:
# Category  Group
# Age       0        0.396005
#           1        0.235140
#           2        0.231278
#           3        0.196187
# Gender    0        0.396005
#           1        0.223508
#           2        0.229411
# Name: Error Rate, dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.barplot(data=df, x='Group', y='Error Rate', hue='Category')
plt.title('Error Rate by Group')
plt.show()

# %%
sns.lineplot(data=df, x='Iteration', y='Error Rate', hue='Group', style='Category')
plt.title('Error Rate Over Iterations')
plt.show()
